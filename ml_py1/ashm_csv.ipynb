# %%
#%matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#pip install -U textblob
import textblob
#pip install -U textblob-de
from textblob_de import TextBlobDE
#pip install seaborn
import seaborn as sns

import nltk

# %%
df = pd.read_csv('D:/refugeeks_project/selenium_py/p1_py/kliniks_Gesamt_liste1.csv') #index_col=0
df.head()
# Out:
#                        Klinik_Name                       Title  \
# 0  HEH Herzogin Elisabeth Hospital                   Bewertung
# 1  HEH Herzogin Elisabeth Hospital               Weiter so HEH
# 2  HEH Herzogin Elisabeth Hospital                 Superklinik
# 3  HEH Herzogin Elisabeth Hospital  Kranken- oder Hotelzimmer?
# 4  HEH Herzogin Elisabeth Hospital                     Knie OP
#
#         Department        Date GesamtListe  \
# 0        Chirurgie  09.06.2021      star-6
# 1        Chirurgie  09.06.2021      star-6
# 2       Orthopädie  07.06.2021      star-6
# 3  Unfallchirurgie  25.05.2021      star-6
# 4       Orthopädie  11.05.2021      star-6
#
#                                               Review
# 0  Sehr höfliche und hilfsbereite Mitarbeiter.\n\...
# 1  Kann ich nur weiterempfehlen!! Sehr gutes Pfle...
# 2  Bestens durchorganisiert.gutes Personal geht i...
# 3  Bin nach einem Autounfall im HEH gewesen und h...
# 4  Wurde bereits im Sept. 2020 am Knie operiert. ...

# %%
df.loc[(df.GesamtListe == 'star-6'), 'GesamtListe'] = 6
df.loc[(df.GesamtListe == 'star-5'), 'GesamtListe'] = 5
df.loc[(df.GesamtListe == 'star-4'), 'GesamtListe'] = 4
df.loc[(df.GesamtListe == 'star-3'), 'GesamtListe'] = 3
df.loc[(df.GesamtListe == 'star-2'), 'GesamtListe'] = 2
df.loc[(df.GesamtListe == 'star-1'), 'GesamtListe'] = 1
df.loc[(df.GesamtListe == 'star-0'), 'GesamtListe'] = 0

# %%
df
# Out:
#                                            Klinik_Name  \
# 0                      HEH Herzogin Elisabeth Hospital
# 1                      HEH Herzogin Elisabeth Hospital
# 2                      HEH Herzogin Elisabeth Hospital
# 3                      HEH Herzogin Elisabeth Hospital
# 4                      HEH Herzogin Elisabeth Hospital
# ..                                                 ...
# 955  Diana Klinik-Fachklinik für Physikalische Medizin
# 956  Diana Klinik-Fachklinik für Physikalische Medizin
# 957  Diana Klinik-Fachklinik für Physikalische Medizin
# 958  Diana Klinik-Fachklinik für Physikalische Medizin
# 959  Diana Klinik-Fachklinik für Physikalische Medizin
#
#                                          Title       Department        Date  \
# 0                                    Bewertung        Chirurgie  09.06.2021
# 1                                Weiter so HEH        Chirurgie  09.06.2021
# 2                                  Superklinik       Orthopädie  07.06.2021
# 3                   Kranken- oder Hotelzimmer?  Unfallchirurgie  25.05.2021
# 4                                      Knie OP       Orthopädie  11.05.2021
# ..                                         ...              ...         ...
# 955                             Sehr zufrieden       Orthopädie  02.11.2018
# 956                             Therapieerfolg       Orthopädie  18.07.2018
# 957                   zu wenig einzelgespräche    Psychosomatik  21.06.2018
# 958                     Empfehlenswerte Klinik    Psychosomatik  18.06.2018
# 959  Sehbehinderte sollten diese Klinik meiden       Neurologie  08.05.2018
#
#     GesamtListe                                             Review
# 0             6  Sehr höfliche und hilfsbereite Mitarbeiter.\n\...
# 1             6  Kann ich nur weiterempfehlen!! Sehr gutes Pfle...
# 2             6  Bestens durchorganisiert.gutes Personal geht i...
# 3             6  Bin nach einem Autounfall im HEH gewesen und h...
# 4             6  Wurde bereits im Sept. 2020 am Knie operiert. ...
# ..          ...                                                ...
# 955           6  Sehr freundliches und hilfsbereites Personal. ...
# 956           4  Direkt aus dem Krankenhaus in die Diana-Klinik...
# 957           4  es hätten mehr gespräche statt finden können b...
# 958           6  Ich war 5 Wochen in der Diana Klinik und habe ...
# 959           0  Sehbehinderte Patienten sollten diese Klinik m...
#
# [960 rows x 6 columns]

# %%
df['GesamtListe'] = df['GesamtListe'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Klinik_Name  960 non-null    object
#  1   Title        959 non-null    object
#  2   Department   958 non-null    object
#  3   Date         960 non-null    object
#  4   GesamtListe  960 non-null    int32
#  5   Review       947 non-null    object
# dtypes: int32(1), object(5)
# memory usage: 41.4+ KB
